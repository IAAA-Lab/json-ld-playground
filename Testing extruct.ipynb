# %% [markdown]
# # Testing struct
#
# _[extruct](https://github.com/scrapinghub/extruct)_ is a library for extracting embedded metadata from HTML markup. It also has a built-in HTTP server to test its output as JSON. _extruct_ supports embedded JSON-LD

# %%
import sys
# !{sys.executable} -m pip install extruct
# Out:
# Requirement already satisfied: extruct in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (0.7.2)
# Requirement already satisfied: lxml in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from extruct) (4.2.5)
# Requirement already satisfied: rdflib-jsonld in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from extruct) (0.4.0)
# Requirement already satisfied: w3lib in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from extruct) (1.20.0)
# Requirement already satisfied: six in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from extruct) (1.12.0)
# Requirement already satisfied: rdflib in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from extruct) (4.2.2)
# Requirement already satisfied: mf2py in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from extruct) (1.1.2)
# Requirement already satisfied: isodate in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from rdflib->extruct) (0.6.0)
# Requirement already satisfied: pyparsing in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from rdflib->extruct) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from mf2py->extruct) (2.21.0)
# Requirement already satisfied: BeautifulSoup4>=4.6.0 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from mf2py->extruct) (4.6.3)
# Requirement already satisfied: html5lib>=1.0.1 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from mf2py->extruct) (1.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from requests>=2.18.4->mf2py->extruct) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from requests>=2.18.4->mf2py->extruct) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from requests>=2.18.4->mf2py->extruct) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from requests>=2.18.4->mf2py->extruct) (2.8)
# Requirement already satisfied: webencodings in /Users/javier/.pyenv/versions/anaconda3-2018.12/lib/python3.7/site-packages (from html5lib>=1.0.1->mf2py->extruct) (0.5.1)

# %% [markdown]
# ## Function Wrapper

# %%
import extruct
import requests
from w3lib.html import get_base_url

def json_ld_from(url):
  r = requests.get(url)
  base_url = get_base_url(r.text, r.url)
  data = extruct.extract(r.text, base_url=base_url)
  return data['json-ld']

# %% [markdown]
# ## Test extraction

# %%
import pprint
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(json_ld_from('https://www.aragon.es/inicio'))
pp.pprint(json_ld_from('https://www.aragon.es/actualidad'))
pp.pprint(json_ld_from('https://www.aragon.es/actualidad/mujer-emprendedora-y-formacion-objetivos-de-la-nueva-edicion-del-programa-de-iniciativas-empresariales-en-aragon'))
pp.pprint(json_ld_from('https://www.aragon.es/politica-de-cookies'))
# Out:
# [ { '@context': { 'dcmi': 'http://purl.org/dc/dcmitype/',
#                   'dct': 'http://purl.org/dc/terms/',
#                   'ei2a': 'http://opendata.aragon.es/def/e2ia#',
#                   'schema': 'http://schema.org/'},
#     '@type': ['ei2a:Document', 'dcmi:InteractiveResource'],
#     'dct:coverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                       '@type': 'schema:Place'},
#     'dct:creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                      '@type': 'schema:GovernmentOrganization',
#                      'schema:name': 'Gobierno de Aragón'},
#     'dct:date': '2019-01-30',
#     'dct:description': '',
#     'dct:format': 'text/html',
#     'dct:language': 'es',
#     'dct:publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                        '@type': 'schema:GovernmentOrganization',
#                        'schema:name': 'Gobierno de Aragón'},
#     'dct:rights': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                     '@type': 'schema:WebPage'},
#     'dct:title': 'Inicio. Gobierno de Aragón'},
#   { '@context': 'http://schema.org/',
#     '@type': ['WebPage', 'WebSite'],
#     'creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                  '@type': 'GovernmentOrganization',
#                  'name': 'Gobierno de Aragón'},
#     'datePublished': '2019-01-30',
#     'description': '',
#     'fileFormat': 'text/html',
#     'inLanguage': 'es',
#     'license': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                  '@type': 'WebPage'},
#     'name': 'Inicio. Gobierno de Aragón',
#     'publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                    '@type': 'GovernmentOrganization',
#                    'name': 'Gobierno de Aragón'},
#     'spatialCoverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                          '@type': 'Place'}},
#   { '@context': 'http://schema.org',
#     '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#     '@type': 'GovernmentOrganization',
#     'contactPoint': [ { '@type': 'ContactPoint',
#                         'contactType': 'customer support',
#                         'telephone': '+34 976714000'}],
#     'logo': { '@type': 'ImageObject',
#               'url': 'https://www.aragon.es/image/company_logo'},
#     'sameAs': [ 'https://www.youtube.com/user/GobiernoAragon',
#                 'https://twitter.com/GobAragon',
#                 'https://www.facebook.com/GobAragon'],
#     'url': 'http://www.aragon.es'}]
# [ { '@context': { 'dcmi': 'http://purl.org/dc/dcmitype/',
#                   'dct': 'http://purl.org/dc/terms/',
#                   'ei2a': 'http://opendata.aragon.es/def/e2ia#',
#                   'schema': 'http://schema.org/'},
#     '@type': ['ei2a:Document', 'dcmi:InteractiveResource'],
#     'dct:coverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                       '@type': 'schema:Place'},
#     'dct:creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                      '@type': 'schema:GovernmentOrganization',
#                      'schema:name': 'Gobierno de Aragón'},
#     'dct:date': '2019-01-10',
#     'dct:description': '',
#     'dct:format': 'text/html',
#     'dct:language': 'es',
#     'dct:publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                        '@type': 'schema:GovernmentOrganization',
#                        'schema:name': 'Gobierno de Aragón'},
#     'dct:rights': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                     '@type': 'schema:WebPage'},
#     'dct:title': 'Actualidad. Gobierno de Aragón'},
#   { '@context': 'http://schema.org/',
#     '@type': ['WebPage', 'WebSite'],
#     'creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                  '@type': 'GovernmentOrganization',
#                  'name': 'Gobierno de Aragón'},
#     'datePublished': '2019-01-10',
#     'description': '',
#     'fileFormat': 'text/html',
#     'inLanguage': 'es',
#     'license': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                  '@type': 'WebPage'},
#     'name': 'Actualidad. Gobierno de Aragón',
#     'publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                    '@type': 'GovernmentOrganization',
#                    'name': 'Gobierno de Aragón'},
#     'spatialCoverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                          '@type': 'Place'}},
#   { '@context': 'http://schema.org',
#     '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#     '@type': 'GovernmentOrganization',
#     'contactPoint': [ { '@type': 'ContactPoint',
#                         'contactType': 'customer support',
#                         'telephone': '+34 976714000'}],
#     'logo': { '@type': 'ImageObject',
#               'url': 'https://www.aragon.es/image/company_logo'},
#     'sameAs': [ 'https://www.youtube.com/user/GobiernoAragon',
#                 'https://twitter.com/GobAragon',
#                 'https://www.facebook.com/GobAragon'],
#     'url': 'http://www.aragon.es'}]
# [ { '@context': { 'dcmi': 'http://purl.org/dc/dcmitype/',
#                   'dct': 'http://purl.org/dc/terms/',
#                   'ei2a': 'http://opendata.aragon.es/def/e2ia#',
#                   'schema': 'http://schema.org/'},
#     '@type': ['ei2a:Document', 'dcmi:InteractiveResource'],
#     'dct:coverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                       '@type': 'schema:Place'},
#     'dct:creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                      '@type': 'schema:GovernmentOrganization',
#                      'schema:name': 'Gobierno de Aragón'},
#     'dct:date': '2019-02-21',
#     'dct:description': 'Las iniciativas seleccionadas aprenden estrategias y '
#                        'técnicas empresariales novedosas que mejoran la '
#                        'gestión del día a día de su actividad emprendedora',
#     'dct:format': 'text/html',
#     'dct:language': 'es',
#     'dct:publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                        '@type': 'schema:GovernmentOrganization',
#                        'schema:name': 'Gobierno de Aragón'},
#     'dct:rights': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                     '@type': 'schema:WebPage'},
#     'dct:title': 'Mujer emprendedora y formación objetivos de la nueva edición '
#                  'del Programa de iniciativas empresariales en Aragón. '
#                  'Gobierno de Aragón'},
#   { '@context': 'http://schema.org/',
#     '@type': ['WebPage', 'WebSite'],
#     'creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                  '@type': 'GovernmentOrganization',
#                  'name': 'Gobierno de Aragón'},
#     'datePublished': '2019-02-21',
#     'description': 'Las iniciativas seleccionadas aprenden estrategias y '
#                    'técnicas empresariales novedosas que mejoran la gestión '
#                    'del día a día de su actividad emprendedora',
#     'fileFormat': 'text/html',
#     'inLanguage': 'es',
#     'license': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                  '@type': 'WebPage'},
#     'name': 'Mujer emprendedora y formación objetivos de la nueva edición del '
#             'Programa de iniciativas empresariales en Aragón. Gobierno de '
#             'Aragón',
#     'publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                    '@type': 'GovernmentOrganization',
#                    'name': 'Gobierno de Aragón'},
#     'spatialCoverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                          '@type': 'Place'}},
#   { '@context': 'http://schema.org',
#     '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#     '@type': 'GovernmentOrganization',
#     'contactPoint': [ { '@type': 'ContactPoint',
#                         'contactType': 'customer support',
#                         'telephone': '+34 976714000'}],
#     'logo': { '@type': 'ImageObject',
#               'url': 'https://www.aragon.es/image/company_logo'},
#     'sameAs': [ 'https://www.youtube.com/user/GobiernoAragon',
#                 'https://twitter.com/GobAragon',
#                 'https://www.facebook.com/GobAragon'],
#     'url': 'http://www.aragon.es'},
#   { '@context': 'http://schema.org/',
#     '@type': 'NewsArticle',
#     'author': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                 '@type': 'GovernmentOrganization',
#                 'name': 'Gobierno de Aragón'},
#     'dateModified': '2019-03-20',
#     'datePublished': '2019-02-21',
#     'headline': 'Mujer emprendedora y formación, objetivos de la nueva edición '
#                 'del Programa de iniciativas empresariales en Ara',
#     'image': 'https://www.aragon.es/documents/20127/184778/programa_mujer_emprendedora.jpg/c18df07f-ea52-cb01-88d4-aa0f7283b7e2?t=1550742362868',
#     'mainEntity': { '@id': 'https://www.aragon.es/actualidad/mujer-emprendedora-y-formacion-objetivos-de-la-nueva-edicion-del-programa-de-iniciativas-empresariales-en-aragon',
#                     '@type': 'WebPage',
#                     'name': 'Mujer emprendedora y formación, objetivos de la '
#                             'nueva edición del Programa de iniciativas '
#                             'empresariales en Ara'},
#     'mainEntityOfPage': { '@id': 'https://www.aragon.es/actualidad/mujer-emprendedora-y-formacion-objetivos-de-la-nueva-edicion-del-programa-de-iniciativas-empresariales-en-aragon#page-title',
#                           '@type': 'WebPage'},
#     'mentions': [ {'@id': 'http://opendata.aragon.es/def/ei2a#ORG002101'},
#                   {'@id': 'http://opendata.aragon.es/def/ei2a#ORG002098'},
#                   { '@id': 'http://opendata.aragon.es/def/ei2a/categorization#SelfEmployedEntrepreneurs'},
#                   { '@id': 'http://opendata.aragon.es/def/ei2a/categorization#EmploymentCoursesAndTraining'}],
#     'publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                    '@type': 'GovernmentOrganization',
#                    'logo': { '@type': 'ImageObject',
#                              'url': 'https://www.aragon.es/image/company_logo'},
#                    'name': 'Gobierno de Aragón'}},
#   { '@context': 'http://schema.org/',
#     '@id': 'http://opendata.aragon.es/def/ei2a#ORG002101',
#     '@type': 'GovernmentOrganization',
#     'name': 'Instituto Aragonés de Fomento'},
#   { '@context': 'http://schema.org/',
#     '@id': 'http://opendata.aragon.es/def/ei2a#ORG002098',
#     '@type': 'GovernmentOrganization',
#     'name': 'Instituto Aragonés de la Mujer'},
#   { '@context': 'http://schema.org/',
#     '@id': 'http://opendata.aragon.es/def/ei2a/categorization#SelfEmployedEntrepreneurs',
#     '@type': 'Thing',
#     'name': 'Emprendedores autónomos'},
#   { '@context': 'http://schema.org/',
#     '@id': 'http://opendata.aragon.es/def/ei2a/categorization#EmploymentCoursesAndTraining',
#     '@type': 'Thing',
#     'name': 'Cursos y formación para emplearse'}]
# [ { '@context': { 'dcmi': 'http://purl.org/dc/dcmitype/',
#                   'dct': 'http://purl.org/dc/terms/',
#                   'ei2a': 'http://opendata.aragon.es/def/e2ia#',
#                   'schema': 'http://schema.org/'},
#     '@type': ['ei2a:Document', 'dcmi:InteractiveResource'],
#     'dct:coverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                       '@type': 'schema:Place'},
#     'dct:creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                      '@type': 'schema:GovernmentOrganization',
#                      'schema:name': 'Gobierno de Aragón'},
#     'dct:date': '2019-01-11',
#     'dct:description': '',
#     'dct:format': 'text/html',
#     'dct:language': 'es',
#     'dct:publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                        '@type': 'schema:GovernmentOrganization',
#                        'schema:name': 'Gobierno de Aragón'},
#     'dct:rights': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                     '@type': 'schema:WebPage'},
#     'dct:title': 'Política de Cookies. Gobierno de Aragón'},
#   { '@context': 'http://schema.org/',
#     '@type': ['WebPage', 'WebSite'],
#     'creator': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                  '@type': 'GovernmentOrganization',
#                  'name': 'Gobierno de Aragón'},
#     'datePublished': '2019-01-11',
#     'description': '',
#     'fileFormat': 'text/html',
#     'inLanguage': 'es',
#     'license': { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#                  '@type': 'WebPage'},
#     'name': 'Política de Cookies. Gobierno de Aragón',
#     'publisher': { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#                    '@type': 'GovernmentOrganization',
#                    'name': 'Gobierno de Aragón'},
#     'spatialCoverage': { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#                          '@type': 'Place'}},
#   { '@context': 'http://schema.org',
#     '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#     '@type': 'GovernmentOrganization',
#     'contactPoint': [ { '@type': 'ContactPoint',
#                         'contactType': 'customer support',
#                         'telephone': '+34 976714000'}],
#     'logo': { '@type': 'ImageObject',
#               'url': 'https://www.aragon.es/image/company_logo'},
#     'sameAs': [ 'https://www.youtube.com/user/GobiernoAragon',
#                 'https://twitter.com/GobAragon',
#                 'https://www.facebook.com/GobAragon'],
#     'url': 'http://www.aragon.es'}]

# %% [markdown]
# ## Test query

# %%
# import sys
# !{sys.executable} -m pip install rdflib-jsonld

# %%
from rdflib import Graph, plugin
from rdflib.serializer import Serializer
import json
s = json.dumps(json_ld_from('https://www.aragon.es/politica-de-cookies'))
g = Graph().parse(publicID='https://www.aragon.es/politica-de-cookies', data=s, format='json-ld')
r = json.loads(g.serialize(format='json-ld'))
pp.pprint(r)
# Out:
# [ { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n',
#     '@type': ['http://schema.org/Place']},
#   { '@id': '_:N0d6096378e444a468556955b588e2005',
#     '@type': [ 'http://purl.org/dc/dcmitype/InteractiveResource',
#                'http://opendata.aragon.es/def/e2ia#Document'],
#     'http://purl.org/dc/terms/coverage': [ { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n'}],
#     'http://purl.org/dc/terms/creator': [ { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon'}],
#     'http://purl.org/dc/terms/date': [{'@value': '2019-01-11'}],
#     'http://purl.org/dc/terms/description': [{'@value': ''}],
#     'http://purl.org/dc/terms/format': [{'@value': 'text/html'}],
#     'http://purl.org/dc/terms/language': [{'@value': 'es'}],
#     'http://purl.org/dc/terms/publisher': [ { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon'}],
#     'http://purl.org/dc/terms/rights': [ { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal'}],
#     'http://purl.org/dc/terms/title': [ { '@value': 'Política de Cookies. '
#                                                     'Gobierno de Aragón'}]},
#   { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon',
#     '@type': ['http://schema.org/GovernmentOrganization'],
#     'http://schema.org/contactPoint': [ { '@id': '_:N68b281d162d54c3daac7f3ea223fcddf'}],
#     'http://schema.org/logo': [{'@id': '_:N333595ed70484dcabb1c6c89c0b18dbf'}],
#     'http://schema.org/name': [{'@value': 'Gobierno de Aragón'}],
#     'http://schema.org/sameAs': [ { '@id': 'https://www.youtube.com/user/GobiernoAragon'},
#                                   {'@id': 'https://twitter.com/GobAragon'},
#                                   { '@id': 'https://www.facebook.com/GobAragon'}],
#     'http://schema.org/url': [{'@id': 'http://www.aragon.es/'}]},
#   { '@id': '_:N68b281d162d54c3daac7f3ea223fcddf',
#     '@type': ['http://schema.org/ContactPoint'],
#     'http://schema.org/contactType': [{'@value': 'customer support'}],
#     'http://schema.org/telephone': [{'@value': '+34 976714000'}]},
#   { '@id': '_:N333595ed70484dcabb1c6c89c0b18dbf',
#     '@type': ['http://schema.org/ImageObject'],
#     'http://schema.org/url': [ { '@id': 'https://www.aragon.es/image/company_logo'}]},
#   { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal',
#     '@type': ['http://schema.org/WebPage']},
#   { '@id': '_:N78d637c555fd444a99067e86c3996806',
#     '@type': ['http://schema.org/WebSite', 'http://schema.org/WebPage'],
#     'http://schema.org/creator': [ { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon'}],
#     'http://schema.org/datePublished': [ { '@type': 'http://schema.org/Date',
#                                            '@value': '2019-01-11'}],
#     'http://schema.org/description': [{'@value': ''}],
#     'http://schema.org/fileFormat': [ { '@id': 'https://www.aragon.es/text/html'}],
#     'http://schema.org/inLanguage': [{'@value': 'es'}],
#     'http://schema.org/license': [ { '@id': 'http://www.aragon.es/EnlacesPie/Aviso_Legal'}],
#     'http://schema.org/name': [ { '@value': 'Política de Cookies. Gobierno de '
#                                             'Aragón'}],
#     'http://schema.org/publisher': [ { '@id': 'http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon'}],
#     'http://schema.org/spatialCoverage': [ { '@id': 'http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n'}]}]

# %%
qres = g.query(
    """SELECT DISTINCT ?a ?b
       WHERE {
          # ?a rdf:type ?b 
       }""")
    
for row in qres:
    print("%s type of %s" % row)
# Out:
# N0d6096378e444a468556955b588e2005 type of http://purl.org/dc/dcmitype/InteractiveResource
# N78d637c555fd444a99067e86c3996806 type of http://schema.org/WebSite
# N68b281d162d54c3daac7f3ea223fcddf type of http://schema.org/ContactPoint
# N78d637c555fd444a99067e86c3996806 type of http://schema.org/WebPage
# N0d6096378e444a468556955b588e2005 type of http://opendata.aragon.es/def/e2ia#Document
# N333595ed70484dcabb1c6c89c0b18dbf type of http://schema.org/ImageObject
# http://opendata.aragon.es/recurso/territorio/ComunidadAutonoma/Arag%C3%B3n type of http://schema.org/Place
# http://opendata.aragon.es/recurso/sectorpublico/organization/gobierno-aragon type of http://schema.org/GovernmentOrganization
# http://www.aragon.es/EnlacesPie/Aviso_Legal type of http://schema.org/WebPage
